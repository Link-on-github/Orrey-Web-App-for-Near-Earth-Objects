# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/nasa-data/sbdb_query_results (1).csv

# %%
df = pd.read_csv("/kaggle/input/nasa-data/sbdb_query_results (1).csv")

# %%
print(df)
# Out:
#             spkid
# 0        20000001
# 1        20000002
# 2        20000003
# 3        20000004
# 4        20000005
# ...           ...
# 1407839   1004026
# 1407840   1004024
# 1407841   1004025
# 1407842   1004027
# 1407843   1004028
#
# [1407844 rows x 1 columns]

# %%
# !pip install astropy
# Out:
# Collecting astropy
#   Downloading astropy-6.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.10/site-packages (from astropy) (1.26.4)
# Collecting pyerfa>=2.0.1.1 (from astropy)
#   Downloading pyerfa-2.0.1.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.7 kB)
# Collecting astropy-iers-data>=0.2024.8.27.10.28.29 (from astropy)
#   Downloading astropy_iers_data-0.2024.9.23.0.31.43-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: PyYAML>=3.13 in /opt/conda/lib/python3.10/site-packages (from astropy) (6.0.2)
# Requirement already satisfied: packaging>=19.0 in /opt/conda/lib/python3.10/site-packages (from astropy) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=19.0->astropy) (3.1.2)
# Downloading astropy-6.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 55.8 MB/s eta 0:00:0000:010:01
# Downloading astropy_iers_data-0.2024.9.23.0.31.43-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 60.1 MB/s eta 0:00:00
# Downloading pyerfa-2.0.1.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (738 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 738.7/738.7 kB 34.9 MB/s eta 0:00:00
# Installing collected packages: pyerfa, astropy-iers-data, astropy
# Successfully installed astropy-6.1.4 astropy-iers-data-0.2024.9.23.0.31.43 pyerfa-2.0.1.4

# %%
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from astropy.coordinates import SkyCoord
import astropy.units as u

def fetch_horizons_data(start_time, stop_time, step_size='1d', des_id='1000165'):
    url = "https://ssd.jpl.nasa.gov/api/horizons.api"
    params = {
        'format': 'text',
        'COMMAND': f"'DES={des_id};'",
        'OBJ_DATA': 'YES',
        'MAKE_EPHEM': 'YES',
        'EPHEM_TYPE': 'OBSERVER',
        'CENTER': '500@399',
        'START_TIME': start_time,
        'STOP_TIME': stop_time,
        'STEP_SIZE': step_size,
        'QUANTITIES': '1'
    }
    response = requests.get(url, params=params)
    return response.text if response.status_code == 200 else None

def parse_horizons_data(data):
    lines = data.split('\n')
    start_idx = lines.index('$$SOE') + 1
    end_idx = lines.index('$$EOE')
    
    dates, ra, dec = [], [], []
    for line in lines[start_idx:end_idx]:
        parts = line.split()
        dates.append(parts[0])
        ra.append(' '.join(parts[2:5]))
        dec.append(' '.join(parts[5:8]))
    
    return dates, ra, dec

def plot_trajectory(dates, ra, dec, title="Asteroid Trajectory"):
    coords = SkyCoord(ra=ra, dec=dec, unit=(u.hourangle, u.deg))
    x = coords.cartesian.x.value
    y = coords.cartesian.y.value
    z = coords.cartesian.z.value

    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')
    ax.plot(x, y, z)
    
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.set_title(title)
    
    plt.show()

# List of IDs to check
ids = df['spkid']  # Add more IDs as needed

# DataFrame to store successful results
results_df = pd.DataFrame(columns=['ID', 'Date', 'RA', 'DEC'])

# Loop through the IDs and fetch data
for des_id in ids:
    data = fetch_horizons_data('2006-01-01', '2007-01-20', des_id=des_id)
    if data:
        try:
            dates, ra, dec = parse_horizons_data(data)
            temp_df = pd.DataFrame({'ID': des_id, 'Date': dates, 'RA': ra, 'DEC': dec})
            results_df = pd.concat([results_df, temp_df], ignore_index=True)
            print(f"Data fetched successfully for ID: {des_id}")
        except Exception as e:
            print(f"Error parsing data for ID: {des_id} - {e}")
    else:
        print(f"Failed to fetch data for ID: {des_id}")

# Display the results DataFrame
print(results_df)

# Optionally, plot the trajectory for one of the successful IDs
if not results_df.empty:
    sample_id = results_df['ID'].iloc[0]
    sample_data = results_df[results_df['ID'] == sample_id]
    plot_trajectory(sample_data['Date'], sample_data['RA'], sample_data['DEC'], title=f"Asteroid {sample_id} Trajectory")
# Out:
# Data fetched successfully for ID: 20000001
# Data fetched successfully for ID: 20000002
# Data fetched successfully for ID: 20000003
# Data fetched successfully for ID: 20000004
# Data fetched successfully for ID: 20000005
# Data fetched successfully for ID: 20000006
# Data fetched successfully for ID: 20000007
# Data fetched successfully for ID: 20000008
# Data fetched successfully for ID: 20000009
# Data fetched successfully for ID: 20000010
# Data fetched successfully for ID: 20000011
# Data fetched successfully for ID: 20000012
# Data fetched successfully for ID: 20000013
# Data fetched successfully for ID: 20000014
# Data fetched successfully for ID: 20000015
# Data fetched successfully for ID: 20000016
# Data fetched successfully for ID: 20000017
# Data fetched successfully for ID: 20000018
# Data fetched successfully for ID: 20000019
# Data fetched successfully for ID: 20000020
# Data fetched successfully for ID: 20000021
# Data fetched successfully for ID: 20000022
# Data fetched successfully for ID: 20000023
# Data fetched successfully for ID: 20000024
# Data fetched successfully for ID: 20000025
# Data fetched successfully for ID: 20000026
# Data fetched successfully for ID: 20000027
# Data fetched successfully for ID: 20000028
# Data fetched successfully for ID: 20000029
# Data fetched successfully for ID: 20000030
# Data fetched successfully for ID: 20000031
# Data fetched successfully for ID: 20000032
# Data fetched successfully for ID: 20000033
# Data fetched successfully for ID: 20000034
# Data fetched successfully for ID: 20000035
# Data fetched successfully for ID: 20000036
# Data fetched successfully for ID: 20000037
# Data fetched successfully for ID: 20000038
# Data fetched successfully for ID: 20000039
# Data fetched successfully for ID: 20000040
# Data fetched successfully for ID: 20000041
# Data fetched successfully for ID: 20000042
# Data fetched successfully for ID: 20000043
# Data fetched successfully for ID: 20000044
# Data fetched successfully for ID: 20000045
# Data fetched successfully for ID: 20000046
# Data fetched successfully for ID: 20000047
# Data fetched successfully for ID: 20000048
# Data fetched successfully for ID: 20000049
# Data fetched successfully for ID: 20000050
# Data fetched successfully for ID: 20000051
# Data fetched successfully for ID: 20000052
# Data fetched successfully for ID: 20000053
# Data fetched successfully for ID: 20000054
# Data fetched successfully for ID: 20000055
# Data fetched successfully for ID: 20000056
# Data fetched successfully for ID: 20000057
# Data fetched successfully for ID: 20000058
# Data fetched successfully for ID: 20000059
# Data fetched successfully for ID: 20000060
# Data fetched successfully for ID: 20000061
# Data fetched successfully for ID: 20000062
# Data fetched successfully for ID: 20000063
# Data fetched successfully for ID: 20000064
# Data fetched successfully for ID: 20000065
# Data fetched successfully for ID: 20000066
# Data fetched successfully for ID: 20000067
# Data fetched successfully for ID: 20000068
# Data fetched successfully for ID: 20000069
# Data fetched successfully for ID: 20000070
# Data fetched successfully for ID: 20000071
# Data fetched successfully for ID: 20000072
# Data fetched successfully for ID: 20000073
# Data fetched successfully for ID: 20000074
# Data fetched successfully for ID: 20000075
# Data fetched successfully for ID: 20000076
# Data fetched successfully for ID: 20000077
# Data fetched successfully for ID: 20000078
# Data fetched successfully for ID: 20000079
# Data fetched successfully for ID: 20000080
# Data fetched successfully for ID: 20000081
# Data fetched successfully for ID: 20000082
# Data fetched successfully for ID: 20000083
# Data fetched successfully for ID: 20000084
# Data fetched successfully for ID: 20000085
# Data fetched successfully for ID: 20000086
# Data fetched successfully for ID: 20000087
# Data fetched successfully for ID: 20000088
# Data fetched successfully for ID: 20000089
# Data fetched successfully for ID: 20000090
# Data fetched successfully for ID: 20000091
# Data fetched successfully for ID: 20000092
# Data fetched successfully for ID: 20000093
# Data fetched successfully for ID: 20000094
# Data fetched successfully for ID: 20000095
# Data fetched successfully for ID: 20000096
# Data fetched successfully for ID: 20000097
# Data fetched successfully for ID: 20000098
# Data fetched successfully for ID: 20000099
# Data fetched successfully for ID: 20000100
# Data fetched successfully for ID: 20000101
# Data fetched successfully for ID: 20000102
# Data fetched successfully for ID: 20000103
# Data fetched successfully for ID: 20000104
# Data fetched successfully for ID: 20000105
# Data fetched successfully for ID: 20000106
# Data fetched successfully for ID: 20000107
# Data fetched successfully for ID: 20000108
# Data fetched successfully for ID: 20000109
# Data fetched successfully for ID: 20000110
# Data fetched successfully for ID: 20000111
# Data fetched successfully for ID: 20000112
# Data fetched successfully for ID: 20000113
# Data fetched successfully for ID: 20000114
# Data fetched successfully for ID: 20000115
# Data fetched successfully for ID: 20000116
# Data fetched successfully for ID: 20000117
# Data fetched successfully for ID: 20000118
# Data fetched successfully for ID: 20000119
# Data fetched successfully for ID: 20000120
# Data fetched successfully for ID: 20000121
# Data fetched successfully for ID: 20000122
# Data fetched successfully for ID: 20000123
# Data fetched successfully for ID: 20000124
# Data fetched successfully for ID: 20000125
# Data fetched successfully for ID: 20000126
# Data fetched successfully for ID: 20000127
# Data fetched successfully for ID: 20000128
# Data fetched successfully for ID: 20000129
# Data fetched successfully for ID: 20000130
# Data fetched successfully for ID: 20000131
# Data fetched successfully for ID: 20000132
# Data fetched successfully for ID: 20000133
# Data fetched successfully for ID: 20000134
# Data fetched successfully for ID: 20000135
# Data fetched successfully for ID: 20000136
# Data fetched successfully for ID: 20000137
# Data fetched successfully for ID: 20000138
# Data fetched successfully for ID: 20000139
# Data fetched successfully for ID: 20000140
# Data fetched successfully for ID: 20000141
# Data fetched successfully for ID: 20000142
# Data fetched successfully for ID: 20000143
# Data fetched successfully for ID: 20000144
# Data fetched successfully for ID: 20000145
# Data fetched successfully for ID: 20000146
# Data fetched successfully for ID: 20000147
# Data fetched successfully for ID: 20000148
# Data fetched successfully for ID: 20000149
# Data fetched successfully for ID: 20000150
# Data fetched successfully for ID: 20000151
# Data fetched successfully for ID: 20000152
# Data fetched successfully for ID: 20000153
# Data fetched successfully for ID: 20000154
# Data fetched successfully for ID: 20000155
# Data fetched successfully for ID: 20000156
# Data fetched successfully for ID: 20000157
# Data fetched successfully for ID: 20000158
# Data fetched successfully for ID: 20000159
# Data fetched successfully for ID: 20000160
# Data fetched successfully for ID: 20000161
# Data fetched successfully for ID: 20000162
# Data fetched successfully for ID: 20000163
# Data fetched successfully for ID: 20000164
# Data fetched successfully for ID: 20000165
# Data fetched successfully for ID: 20000166
# Data fetched successfully for ID: 20000167
# Data fetched successfully for ID: 20000168
# Data fetched successfully for ID: 20000169
# Data fetched successfully for ID: 20000170
# Data fetched successfully for ID: 20000171
# Data fetched successfully for ID: 20000172
# Data fetched successfully for ID: 20000173
# Data fetched successfully for ID: 20000174
# Data fetched successfully for ID: 20000175
# Data fetched successfully for ID: 20000176
# Data fetched successfully for ID: 20000177
# Data fetched successfully for ID: 20000178
# Data fetched successfully for ID: 20000179
# Data fetched successfully for ID: 20000180
# Data fetched successfully for ID: 20000181
# Data fetched successfully for ID: 20000182
# Data fetched successfully for ID: 20000183
# Data fetched successfully for ID: 20000184
# Data fetched successfully for ID: 20000185
# Data fetched successfully for ID: 20000186
# Data fetched successfully for ID: 20000187
# Data fetched successfully for ID: 20000188
# Data fetched successfully for ID: 20000189
# Data fetched successfully for ID: 20000190
# Data fetched successfully for ID: 20000191
# Data fetched successfully for ID: 20000192
# Data fetched successfully for ID: 20000193
# Data fetched successfully for ID: 20000194
# Data fetched successfully for ID: 20000195
# Data fetched successfully for ID: 20000196
# Data fetched successfully for ID: 20000197
# Data fetched successfully for ID: 20000198
# Data fetched successfully for ID: 20000199
# Data fetched successfully for ID: 20000200
# Data fetched successfully for ID: 20000201
# Data fetched successfully for ID: 20000202
# Data fetched successfully for ID: 20000203
# Data fetched successfully for ID: 20000204
# Data fetched successfully for ID: 20000205
# Data fetched successfully for ID: 20000206
# Data fetched successfully for ID: 20000207
# Data fetched successfully for ID: 20000208
# Data fetched successfully for ID: 20000209
# Data fetched successfully for ID: 20000210
# Data fetched successfully for ID: 20000211
# Data fetched successfully for ID: 20000212
# Data fetched successfully for ID: 20000213
# Data fetched successfully for ID: 20000214
# Data fetched successfully for ID: 20000215
# Data fetched successfully for ID: 20000216
# Data fetched successfully for ID: 20000217
# Data fetched successfully for ID: 20000218
# Data fetched successfully for ID: 20000219
# Data fetched successfully for ID: 20000220
# Data fetched successfully for ID: 20000221
# Data fetched successfully for ID: 20000222
# Data fetched successfully for ID: 20000223
# Data fetched successfully for ID: 20000224
# Data fetched successfully for ID: 20000225
# Data fetched successfully for ID: 20000226
# Data fetched successfully for ID: 20000227
# Data fetched successfully for ID: 20000228
# Data fetched successfully for ID: 20000229
# Data fetched successfully for ID: 20000230
# Data fetched successfully for ID: 20000231
# Data fetched successfully for ID: 20000232
# Data fetched successfully for ID: 20000233
# Data fetched successfully for ID: 20000234
# Data fetched successfully for ID: 20000235
# Data fetched successfully for ID: 20000236
# Data fetched successfully for ID: 20000237
# Data fetched successfully for ID: 20000238
# Data fetched successfully for ID: 20000239
# Data fetched successfully for ID: 20000240
# Data fetched successfully for ID: 20000241
# Data fetched successfully for ID: 20000242
# Data fetched successfully for ID: 20000243
# Data fetched successfully for ID: 20000244
# Data fetched successfully for ID: 20000245
# Data fetched successfully for ID: 20000246
# Data fetched successfully for ID: 20000247
# Data fetched successfully for ID: 20000248
# Data fetched successfully for ID: 20000249
# Data fetched successfully for ID: 20000250
# Data fetched successfully for ID: 20000251
# Data fetched successfully for ID: 20000252
# Data fetched successfully for ID: 20000253
# Data fetched successfully for ID: 20000254
# Data fetched successfully for ID: 20000255
# Data fetched successfully for ID: 20000256
# Data fetched successfully for ID: 20000257
# Data fetched successfully for ID: 20000258
# Data fetched successfully for ID: 20000259
# Data fetched successfully for ID: 20000260
# Data fetched successfully for ID: 20000261
# Data fetched successfully for ID: 20000262
# Data fetched successfully for ID: 20000263
# Data fetched successfully for ID: 20000264
# Data fetched successfully for ID: 20000265
# Data fetched successfully for ID: 20000266
# Data fetched successfully for ID: 20000267
# Data fetched successfully for ID: 20000268
# Data fetched successfully for ID: 20000269
# Data fetched successfully for ID: 20000270
# Data fetched successfully for ID: 20000271
# Data fetched successfully for ID: 20000272
# Data fetched successfully for ID: 20000273
# Data fetched successfully for ID: 20000274
# Data fetched successfully for ID: 20000275
# Data fetched successfully for ID: 20000276
# Data fetched successfully for ID: 20000277
# Data fetched successfully for ID: 20000278
# Data fetched successfully for ID: 20000279
# Data fetched successfully for ID: 20000280
# Data fetched successfully for ID: 20000281
# Data fetched successfully for ID: 20000282
# Data fetched successfully for ID: 20000283
# Data fetched successfully for ID: 20000284
# Data fetched successfully for ID: 20000285
# Data fetched successfully for ID: 20000286
# Data fetched successfully for ID: 20000287
# Data fetched successfully for ID: 20000288
# Data fetched successfully for ID: 20000289
# Data fetched successfully for ID: 20000290
# Data fetched successfully for ID: 20000291
# Data fetched successfully for ID: 20000292
# Data fetched successfully for ID: 20000293
# Data fetched successfully for ID: 20000294
# Data fetched successfully for ID: 20000295
# Data fetched successfully for ID: 20000296
# Data fetched successfully for ID: 20000297
# Data fetched successfully for ID: 20000298
# Data fetched successfully for ID: 20000299
# Data fetched successfully for ID: 20000300
# Data fetched successfully for ID: 20000301
# Data fetched successfully for ID: 20000302
# Data fetched successfully for ID: 20000303
# Data fetched successfully for ID: 20000304
# Data fetched successfully for ID: 20000305
# Data fetched successfully for ID: 20000306
# Data fetched successfully for ID: 20000307
# Data fetched successfully for ID: 20000308
# Data fetched successfully for ID: 20000309
# Data fetched successfully for ID: 20000310
# Data fetched successfully for ID: 20000311
# Data fetched successfully for ID: 20000312
# Data fetched successfully for ID: 20000313
# Data fetched successfully for ID: 20000314
# Data fetched successfully for ID: 20000315
# Data fetched successfully for ID: 20000316
# Data fetched successfully for ID: 20000317
# Data fetched successfully for ID: 20000318
# Data fetched successfully for ID: 20000319
# Data fetched successfully for ID: 20000320
# Data fetched successfully for ID: 20000321
# Data fetched successfully for ID: 20000322
# Data fetched successfully for ID: 20000323
# Data fetched successfully for ID: 20000324
# Data fetched successfully for ID: 20000325
# Data fetched successfully for ID: 20000326
# Data fetched successfully for ID: 20000327
# Data fetched successfully for ID: 20000328
# Data fetched successfully for ID: 20000329
# Data fetched successfully for ID: 20000330
# Data fetched successfully for ID: 20000331
# Data fetched successfully for ID: 20000332
# Data fetched successfully for ID: 20000333
# Data fetched successfully for ID: 20000334
# Data fetched successfully for ID: 20000335
# Data fetched successfully for ID: 20000336
# Data fetched successfully for ID: 20000337
# Data fetched successfully for ID: 20000338
# Data fetched successfully for ID: 20000339
# Data fetched successfully for ID: 20000340
# Data fetched successfully for ID: 20000341
# Data fetched successfully for ID: 20000342
# Data fetched successfully for ID: 20000343
# Data fetched successfully for ID: 20000344
# Data fetched successfully for ID: 20000345
# Data fetched successfully for ID: 20000346
# Data fetched successfully for ID: 20000347
# Data fetched successfully for ID: 20000348
# Data fetched successfully for ID: 20000349
# Data fetched successfully for ID: 20000350
# Data fetched successfully for ID: 20000351
# Data fetched successfully for ID: 20000352
# Data fetched successfully for ID: 20000353
# Data fetched successfully for ID: 20000354
# Data fetched successfully for ID: 20000355
# Data fetched successfully for ID: 20000356
# Data fetched successfully for ID: 20000357
# Data fetched successfully for ID: 20000358
# Data fetched successfully for ID: 20000359
# Data fetched successfully for ID: 20000360
# Data fetched successfully for ID: 20000361
# Data fetched successfully for ID: 20000362
# Data fetched successfully for ID: 20000363
# Data fetched successfully for ID: 20000364
# Data fetched successfully for ID: 20000365
# Data fetched successfully for ID: 20000366
# Data fetched successfully for ID: 20000367
# Data fetched successfully for ID: 20000368
# Data fetched successfully for ID: 20000369
# Data fetched successfully for ID: 20000370
# Data fetched successfully for ID: 20000371
# Data fetched successfully for ID: 20000372
# Data fetched successfully for ID: 20000373
# Data fetched successfully for ID: 20000374
# Data fetched successfully for ID: 20000375
# Data fetched successfully for ID: 20000376
# Data fetched successfully for ID: 20000377
# Data fetched successfully for ID: 20000378
# Data fetched successfully for ID: 20000379
# Data fetched successfully for ID: 20000380
# Data fetched successfully for ID: 20000381
# Data fetched successfully for ID: 20000382
# Data fetched successfully for ID: 20000383
# Data fetched successfully for ID: 20000384
# Data fetched successfully for ID: 20000385
# Data fetched successfully for ID: 20000386
# Data fetched successfully for ID: 20000387
# Data fetched successfully for ID: 20000388
# Data fetched successfully for ID: 20000389
# Data fetched successfully for ID: 20000390
# Data fetched successfully for ID: 20000391
# Data fetched successfully for ID: 20000392
# Data fetched successfully for ID: 20000393
# Data fetched successfully for ID: 20000394
# Data fetched successfully for ID: 20000395
# Data fetched successfully for ID: 20000396
# Data fetched successfully for ID: 20000397
# Data fetched successfully for ID: 20000398
# Data fetched successfully for ID: 20000399
# Data fetched successfully for ID: 20000400
# Data fetched successfully for ID: 20000401
# Data fetched successfully for ID: 20000402
# Data fetched successfully for ID: 20000403
# Data fetched successfully for ID: 20000404
# Data fetched successfully for ID: 20000405
# Data fetched successfully for ID: 20000406
# Data fetched successfully for ID: 20000407
# Data fetched successfully for ID: 20000408
# Data fetched successfully for ID: 20000409
# Data fetched successfully for ID: 20000410
# Data fetched successfully for ID: 20000411
# Data fetched successfully for ID: 20000412
# Data fetched successfully for ID: 20000413
# Data fetched successfully for ID: 20000414
# Data fetched successfully for ID: 20000415
# Data fetched successfully for ID: 20000416
# Data fetched successfully for ID: 20000417
# Data fetched successfully for ID: 20000418
# Data fetched successfully for ID: 20000419
# Data fetched successfully for ID: 20000420
# Data fetched successfully for ID: 20000421
# Data fetched successfully for ID: 20000422
# Data fetched successfully for ID: 20000423
# Data fetched successfully for ID: 20000424
# Data fetched successfully for ID: 20000425
# Data fetched successfully for ID: 20000426
# Data fetched successfully for ID: 20000427
# Data fetched successfully for ID: 20000428
# Data fetched successfully for ID: 20000429
# Data fetched successfully for ID: 20000430
# Data fetched successfully for ID: 20000431
# Data fetched successfully for ID: 20000432
# Data fetched successfully for ID: 20000433
# Data fetched successfully for ID: 20000434
# Data fetched successfully for ID: 20000435
# Data fetched successfully for ID: 20000436
# Data fetched successfully for ID: 20000437
# Data fetched successfully for ID: 20000438
# Data fetched successfully for ID: 20000439
# Data fetched successfully for ID: 20000440
# Data fetched successfully for ID: 20000441
# Data fetched successfully for ID: 20000442
# Data fetched successfully for ID: 20000443
# Data fetched successfully for ID: 20000444
# Data fetched successfully for ID: 20000445
# Data fetched successfully for ID: 20000446
# Data fetched successfully for ID: 20000447
# Data fetched successfully for ID: 20000448
# Data fetched successfully for ID: 20000449
# Data fetched successfully for ID: 20000450
# Data fetched successfully for ID: 20000451
# Data fetched successfully for ID: 20000452
# Data fetched successfully for ID: 20000453
# Data fetched successfully for ID: 20000454
# Data fetched successfully for ID: 20000455
# Data fetched successfully for ID: 20000456
# Data fetched successfully for ID: 20000457
# Data fetched successfully for ID: 20000458
# Data fetched successfully for ID: 20000459
# Data fetched successfully for ID: 20000460
# Data fetched successfully for ID: 20000461
# Data fetched successfully for ID: 20000462
# Data fetched successfully for ID: 20000463
# Data fetched successfully for ID: 20000464
# Data fetched successfully for ID: 20000465
# Data fetched successfully for ID: 20000466
# Data fetched successfully for ID: 20000467
# Data fetched successfully for ID: 20000468
# Data fetched successfully for ID: 20000469
# Data fetched successfully for ID: 20000470
# Data fetched successfully for ID: 20000471
# Data fetched successfully for ID: 20000472
# Data fetched successfully for ID: 20000473
# Data fetched successfully for ID: 20000474
# Data fetched successfully for ID: 20000475
# Data fetched successfully for ID: 20000476
# Data fetched successfully for ID: 20000477
# Data fetched successfully for ID: 20000478
# Data fetched successfully for ID: 20000479
# Data fetched successfully for ID: 20000480
# Data fetched successfully for ID: 20000481
# Data fetched successfully for ID: 20000482
# Data fetched successfully for ID: 20000483
# Data fetched successfully for ID: 20000484
# Data fetched successfully for ID: 20000485
# Data fetched successfully for ID: 20000486
# Data fetched successfully for ID: 20000487
# Data fetched successfully for ID: 20000488
# Data fetched successfully for ID: 20000489
# Data fetched successfully for ID: 20000490
# Data fetched successfully for ID: 20000491
# Data fetched successfully for ID: 20000492
# Data fetched successfully for ID: 20000493
# Data fetched successfully for ID: 20000494
# Data fetched successfully for ID: 20000495
# Data fetched successfully for ID: 20000496
# Data fetched successfully for ID: 20000497
# Data fetched successfully for ID: 20000498
# Data fetched successfully for ID: 20000499
# Data fetched successfully for ID: 20000500
# Data fetched successfully for ID: 20000501
# Data fetched successfully for ID: 20000502
# Data fetched successfully for ID: 20000503
# Data fetched successfully for ID: 20000504
# Data fetched successfully for ID: 20000505
# Data fetched successfully for ID: 20000506
# Data fetched successfully for ID: 20000507
# Data fetched successfully for ID: 20000508
# Data fetched successfully for ID: 20000509
# Data fetched successfully for ID: 20000510
# Data fetched successfully for ID: 20000511
# Data fetched successfully for ID: 20000512
# Data fetched successfully for ID: 20000513
